# %%
import os
import csv
import re
import sample_package.commonFunction as basefunc
import sample_package.filterMethod as filter_TFID
from nltk.corpus import stopwords

from datetime import datetime
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from numpy  import array
import numpy as np
from scipy.misc import toimage

# = function 

# = init

sid = SentimentIntensityAnalyzer()

foundCnt = 0;
foundMax = 1000;
sentimentCnt =3
lenght = 27
magicNumber = lenght*lenght
zt = []
yt = []


# = main 

# get Game Infomation

    
print("--- programming start---")
teamNameList = ["Thunder","Spurs","Blazers","Grizzlies"] # , "Blazers","Grizzlies","Thunder"

for teamName in teamNameList:

    gameInfo = basefunc.getGameInfo(teamName);

    for eachGameInfo in gameInfo:

        # Game data and time
        gameDate = eachGameInfo.Date
        gameTime = eachGameInfo.Time


        print("Team: {} Date: {} {}".format(teamName, gameDate, eachGameInfo.result))
        fileName = basefunc.getCvsPathByGameData(teamName, gameDate)
        foundCnt+=1

        if(len(fileName)>=1):
        # read file to ...
            tweetsfile = open(fileName[0], 'r')
            tweets = csv.reader(tweetsfile)
            csvTitle = next(tweets, None)

            tweetCnt = 0
            totalList =[]
            
            # get each tweet
            for row in tweets:
                
                # get tweet's sentiment
                tpresult = sid.polarity_scores(row[0])
    #             print(tpresult)
                if(tpresult["compound"] != 0):
                    tweetCnt+=1
                    tplist = [tpresult['neg'], tpresult['neu'],tpresult['pos'],tpresult['compound']]
                    totalList.append(tplist)
                if(tweetCnt>=magicNumber):
                    break

            if len(totalList) == magicNumber:
                a = array(totalList)
                b = a[a[:, 3].argsort()]
                c = b.tolist()
                zt.append(c)
                if(eachGameInfo.result == "W"):
                    yt.append(0)
                else:
                    yt.append(1)

        # show only one result then break
        if foundCnt >= foundMax:
            break;
        
        

x_result = array( zt )
y_result = array( yt)
print(x_result.shape)
print(y_result.shape)
print("--- programming end---")
# Out:
# --- programming start---
# Get result from /Users/cosoet/SIT/BIA660-WebAnalytics/FinalProject/GameResult/Thunder.csv
# Team: Thunder Date: 2016-10-26 W
# Team: Thunder Date: 2016-10-28 W
# Team: Thunder Date: 2016-10-30 W
# Team: Thunder Date: 2016-11-02 W
# Team: Thunder Date: 2016-11-03 L
# Team: Thunder Date: 2016-11-05 W
# Team: Thunder Date: 2016-11-07 W
# Team: Thunder Date: 2016-11-09 L
# Team: Thunder Date: 2016-11-11 L
# Team: Thunder Date: 2016-11-13 L
# Team: Thunder Date: 2016-11-14 L
# Team: Thunder Date: 2016-11-16 W
# Team: Thunder Date: 2016-11-18 W
# Team: Thunder Date: 2016-11-20 L
# Team: Thunder Date: 2016-11-22 L
# Team: Thunder Date: 2016-11-23 L
# Team: Thunder Date: 2016-11-25 W
# Team: Thunder Date: 2016-11-26 W
# Team: Thunder Date: 2016-11-28 W
# Team: Thunder Date: 2016-11-30 W
# Team: Thunder Date: 2016-12-04 W
# Team: Thunder Date: 2016-12-05 W
# Team: Thunder Date: 2016-12-09 L
# Team: Thunder Date: 2016-12-11 W
# Team: Thunder Date: 2016-12-13 L
# Team: Thunder Date: 2016-12-14 L
# Team: Thunder Date: 2016-12-17 W
# Team: Thunder Date: 2016-12-19 L
# Team: Thunder Date: 2016-12-21 W
# Team: Thunder Date: 2016-12-23 W
# Team: Thunder Date: 2016-12-25 W
# Team: Grizzlies Date: 2016-11-08 W
# Team: Grizzlies Date: 2016-11-12 L
# Team: Grizzlies Date: 2016-11-14 W
# Team: Grizzlies Date: 2016-11-16 W
# Team: Grizzlies Date: 2016-11-18 W
# Team: Grizzlies Date: 2016-11-19 W

# %%
import numpy as np
import seaborn as sns
import pandas as pd

# show the sentiment table as an image

pal = sns.dark_palette("white", as_cmap=True)
df1 = pd.DataFrame(x_result[1])
sns.heatmap(df1, cmap=pal, yticklabels=False);

# %%
from keras.utils import np_utils
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(\
                x_result, y_result, test_size=0.1, random_state=0)

print(X_train.shape)
print(X_train)
# Out:
# /Users/cosoet/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# (212, 729, 4)
# [[[ 0.29    0.71    0.     -0.874 ]
#   [ 0.412   0.512   0.077  -0.8706]
#   [ 0.66    0.34    0.     -0.8658]
#   ...
#   [ 0.      0.404   0.596   0.9642]
#   [ 0.081   0.334   0.585   0.9643]
#   [ 0.      0.446   0.554   0.9678]]
#
#  [[ 0.601   0.399   0.     -0.9393]
#   [ 0.5     0.5     0.     -0.9186]
#   [ 0.577   0.423   0.     -0.8979]
#   ...
#   [ 0.049   0.549   0.402   0.9118]
#   [ 0.      0.474   0.526   0.949 ]
#   [ 0.039   0.39    0.571   0.9567]]
#
#  [[ 0.445   0.555   0.     -0.9433]
#   [ 0.327   0.673   0.     -0.8658]
#   [ 0.365   0.635   0.     -0.8478]
#   ...
#   [ 0.      0.566   0.434   0.9331]
#   [ 0.      0.424   0.576   0.9393]
#   [ 0.      0.09    0.91    0.9903]]
#
#  ...
#
#  [[ 0.724   0.149   0.127  -0.9801]
#   [ 0.461   0.539   0.     -0.9371]
#   [ 0.319   0.681   0.     -0.9136]
#   ...
#   [ 0.      0.55    0.45    0.9403]
#   [ 0.      0.437   0.563   0.9652]
#   [ 0.      0.389   0.611   0.9737]]
#
#  [[ 0.545   0.455   0.     -0.9211]
#   [ 0.414   0.586   0.     -0.8999]
#   [ 0.383   0.617   0.     -0.8841]
#   ...
#   [ 0.      0.489   0.511   0.9493]
#   [ 0.      0.458   0.542   0.9578]
#   [ 0.088   0.37    0.542   0.9647]]
#
#  [[ 0.376   0.624   0.     -0.9195]
#   [ 0.425   0.575   0.     -0.9189]
#   [ 0.456   0.456   0.088  -0.8717]
#   ...
#   [ 0.      0.6     0.4     0.9516]
#   [ 0.      0.495   0.505   0.954 ]
#   [ 0.      0.439   0.561   0.9647]]]

# %%
from keras.utils import np_utils
x_Train4D=X_train.reshape(X_train.shape[0],729,4,1).astype('float32')
x_Test4D=X_test.reshape(X_test.shape[0],729,4,1).astype('float32')
y_TrainOneHot = np_utils.to_categorical(y_train)

# %%
x_Train4D.shape
# Out:
# (212, 729, 4, 1)

# %%
import numpy as np
import pandas as pd
import keras
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten,Conv2D,MaxPooling2D
from keras.callbacks import EarlyStopping

# %%
model = Sequential()

# CNN first layer
model.add(Conv2D(filters=16,
                 kernel_size=(3,3),
                 padding='same',
                 input_shape=(729,4,1), 
                 activation='relu'))
# CNN second layer
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=36,
                 kernel_size=(2,2),
                 padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))
model.add(Conv2D(filters=48,
                 kernel_size=(1,1),
                 padding='same',
                 activation='relu'))
model.add(MaxPooling2D(pool_size=(1, 1)))

# %%
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2,activation='sigmoid'))

# %%
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 729, 4, 16)        160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 364, 2, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 364, 2, 36)        2340
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 364, 2, 36)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 364, 2, 48)        1776
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 364, 2, 48)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 364, 2, 48)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 34944)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4472960
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 4,477,494
# Trainable params: 4,477,494
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# set the early stop
early_stopping = EarlyStopping(monitor='val_loss', patience=10)
model.compile(loss='binary_crossentropy', optimizer='rmsprop',metrics=['accuracy'])

train_history=model.fit(x=x_Train4D, 
                        y=y_TrainOneHot,validation_split=0.2, 
                        epochs=45, batch_size=20,verbose=2,callbacks=[early_stopping]) #,callbacks=[early_stopping]
# Out:
# Train on 169 samples, validate on 43 samples
# Epoch 1/45
#  - 2s - loss: 0.9118 - acc: 0.5296 - val_loss: 0.7007 - val_acc: 0.4419
# Epoch 2/45
#  - 1s - loss: 0.7037 - acc: 0.5651 - val_loss: 0.6866 - val_acc: 0.5581
# Epoch 3/45
#  - 1s - loss: 0.6735 - acc: 0.6124 - val_loss: 0.6876 - val_acc: 0.5581
# Epoch 4/45
#  - 1s - loss: 0.6802 - acc: 0.5947 - val_loss: 0.6862 - val_acc: 0.5581
# Epoch 5/45
#  - 1s - loss: 0.6573 - acc: 0.6065 - val_loss: 0.6879 - val_acc: 0.5581
# Epoch 6/45
#  - 1s - loss: 0.6705 - acc: 0.6065 - val_loss: 0.6929 - val_acc: 0.5581
# Epoch 7/45
#  - 1s - loss: 0.6560 - acc: 0.6213 - val_loss: 0.7212 - val_acc: 0.5581
# Epoch 8/45
#  - 1s - loss: 0.6448 - acc: 0.6183 - val_loss: 0.7312 - val_acc: 0.5581
# Epoch 9/45
#  - 1s - loss: 0.6363 - acc: 0.6302 - val_loss: 0.6836 - val_acc: 0.5581
# Epoch 10/45
#  - 1s - loss: 0.6080 - acc: 0.6686 - val_loss: 0.7022 - val_acc: 0.5581
# Epoch 11/45
#  - 1s - loss: 0.5857 - acc: 0.6982 - val_loss: 0.6851 - val_acc: 0.5233
# Epoch 12/45
#  - 1s - loss: 0.5727 - acc: 0.7337 - val_loss: 0.6892 - val_acc: 0.5581
# Epoch 13/45
#  - 1s - loss: 0.5311 - acc: 0.7633 - val_loss: 0.6911 - val_acc: 0.5581
# Epoch 14/45
#  - 1s - loss: 0.4864 - acc: 0.8077 - val_loss: 0.7053 - val_acc: 0.5349
# Epoch 15/45
#  - 1s - loss: 0.4265 - acc: 0.8284 - val_loss: 0.7010 - val_acc: 0.5116
# Epoch 16/45
#  - 1s - loss: 0.3773 - acc: 0.9024 - val_loss: 0.7421 - val_acc: 0.4767
# Epoch 17/45
#  - 1s - loss: 0.3405 - acc: 0.9024 - val_loss: 0.7833 - val_acc: 0.5233
# Epoch 18/45
#  - 1s - loss: 0.2748 - acc: 0.9379 - val_loss: 0.8952 - val_acc: 0.5116
# Epoch 19/45
#  - 1s - loss: 0.2479 - acc: 0.9349 - val_loss: 0.8201 - val_acc: 0.5349

# %%
import matplotlib.pyplot as plt
def show_train_history(train_acc,test_acc):
    plt.plot(train_history.history[train_acc])
    plt.plot(train_history.history[test_acc])
    plt.title('Train History')
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
show_train_history('acc','val_acc')
show_train_history('loss','val_loss')

y_TestOneHot = np_utils.to_categorical(y_test)


scores = model.evaluate(x_Test4D , y_TestOneHot)
scores[1]
# Out:
# 24/24 [==============================] - 0s 2ms/step
# 0.6875
